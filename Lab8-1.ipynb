# %%
print("helloworld")
# Out:
# helloworld

# %%
name = int(input("ชื่อพนักงาน"))
pay = int(input("เงินเดือน"))
้้็hour = int(input("ชั่วโมง"))
over = 0 
def xxx(name,pay,hour):
    if over>40
     hour
    else
